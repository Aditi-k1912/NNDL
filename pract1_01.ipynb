# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi-k1912/NNDL/blob/main/pract1_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

vector1 = np.array([10,20,30])
vector2 = np.array([10,30,50])
print("Vector 1 = ", vector1)
print("Vector 2 = ", vector2)
addition = vector1 + vector2

print("Vector Addition = ", addition)
print()
A = np.array([[1,2],
[3,4]])
B = np.array([[5,6],
[7,8]])
print("Matrix A")
print(A)
print()
print("Matrix B")
print(B)
print()
C = np.matmul(A,B)
print("Matrix Multiplication")
print(C)
# Out:
# Vector 1 =  [10 20 30]
# Vector 2 =  [ 5 10 15]
# Vector Addition =  [15 30 45]
#
# Matrix A
# [[1 2]
#  [3 4]]
#
# Matrix B
# [[5 6]
#  [7 8]]
#
# Matrix Multiplication
# [[19 22]
#  [43 50]]
